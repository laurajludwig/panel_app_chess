# %% [markdown]
# ## Panel App Notebook
#
# This notebook is a testing ground for building out the script in Panel that we'll the port over into the PyScript tags in the html elsewhere. This notebook started with the code for the calendar example, and we can modify as needed to adjust our own purpose.

# %%
## import packages
import panel as pn
import pandas as pd
import geopandas as gpd
import holoviews as hv
import hvplot.pandas
import numpy as np

# %%
data = pd.read_csv('../data/combined/finish.dat', names=['yr_month', 'geo', 'count'])

# %%
time_ls = list(set(df['label_friendly']))

# %%
time_ls.sort()

# %%
df['size']=df['count']*df['count']

# %%
plot = df[df['label_friendly']=='2022-Q1'].hvplot.points("Longitude","Latitude", s='size',
                        geo=True, tiles="CartoLight", min_height=500,
                        xaxis=None, yaxis=None, responsive=True,
                        title='Grandmaster Migration Patterns 2001-2023')
plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (size)

# %%
## panel settings
pn.extension(sizing_mode="stretch_width")

## panel widgets
time_slider = pn.widgets.DiscreteSlider(name='Time period', options=time_ls, value="2001-Q1")

## callback functions
def compute_df(date):
    new_df = df[df['label_friendly']==date]
    return new_df

def compute_plot(df):
    return df.hvplot.points("Longitude","Latitude", s='size',
                        geo=True, tiles="CartoLight", min_height=500,
                        xaxis=None, yaxis=None, responsive=True)
    
    #return plot

## panel layout and render in-notebook
pn.Column(
    "# Grandmaster Migration Patterns 2001-2023", 
    pn.bind(compute_plot, pn.bind(compute_df, time_slider)),
    time_slider
).servable(target='simple_app')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Column(design=<class 'panel.theme.materi..., sizing_mode='stretch_width')
#     [0] Markdown(str, design=<class 'panel.theme.materi..., sizing_mode='stretch_width')
#     [1] ParamFunction(function, _pane=HoloViews, defer_load=False, design=<class 'panel.theme.materi..., sizing_mode='stretch_width')
# ...
